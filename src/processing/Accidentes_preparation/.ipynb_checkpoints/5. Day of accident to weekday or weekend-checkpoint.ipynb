# %% [markdown]
# ## Preparación de Datos (Accidentes) paso 5: Dias de semana/fines de semana
#
# Para finalizar la limpieza del dataset *Accidentes.csv* la columna *DIA_ACCIDENTE* es agrupada para obtener si el día del accidente es un dia laboral de semana (Lun - Jue) o fin de semana (Vie - Dom). Conocer esto nos permitirá en la fase de análisis estudiar patrones en los accidentes a partir del tipo de dia se la semana en el que ocurre.
#
# ### Lectura del último dataset
# Se importa la ultima version de los datos aplicando el formato de fecha a la columna *FECHA_ACCIDENTE*

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('Accidentes_clusters.csv')
df['FECHA_ACCIDENTE'] = pd.to_datetime(df['FECHA_ACCIDENTE'], format='%Y-%m-%d %H:%M:%S')
df.head(10)
# Out:
#       FECHA_ACCIDENTE  AÑO_ACCIDENTE  MES_ACCIDENTE DIA_ACCIDENTE  \
# 0 2017-12-24 21:30:00           2017             12           Dom
# 1 2015-01-01 14:10:00           2015              1           Jue
# 2 2015-01-01 14:15:00           2015              1           Jue
# 3 2015-01-01 14:20:00           2015              1           Jue
# 4 2015-01-01 15:30:00           2015              1           Jue
# 5 2015-01-01 04:20:00           2015              1           Jue
# 6 2015-01-01 16:40:00           2015              1           Jue
# 7 2015-01-01 16:50:00           2015              1           Jue
# 8 2015-01-01 06:00:00           2015              1           Jue
# 9 2015-01-01 19:50:00           2015              1           Jue
#
#   HORA_ACCIDENTE MOMENTO_DIA GRAVEDAD_ACCIDENTE CLASE_ACCIDENTE  \
# 0    09:30:00:PM       Noche        Con heridos          Choque
# 1    02:10:00:PM       Tarde        Con heridos          Choque
# 2    02:15:00:PM       Tarde         Solo daños          Choque
# 3    02:20:00:PM       Tarde         Solo daños          Choque
# 4    03:30:00:PM       Tarde        Con heridos          Choque
# 5    04:20:00:AM   Madrugada         Solo daños          Choque
# 6    04:40:00:PM       Tarde        Con heridos          Choque
# 7    04:50:00:PM       Tarde        Con heridos       Atropello
# 8    06:00:00:AM      Mañana         Solo daños          Choque
# 9    07:50:00:PM       Noche         Solo daños          Choque
#
#   SITIO_EXACTO_ACCIDENTE    LATITUD   LONGITUD  \
# 0            CR 6  CL 94  10.946586 -74.826513
# 1          VIA 40 CON 77  11.016189 -74.795327
# 2         CALLE 14 CR 13  10.952965 -74.771882
# 3           CL 74 CR 38C  10.985707 -74.812420
# 4            CL 45 CR 19  10.958396 -74.794710
# 5         CRA 15 CLLE 21  10.953501 -74.776203
# 6         CRA 14 CLLE 35  10.951457 -74.788801
# 7          CRA 6 CLLE 90  10.944943 -74.823909
# 8          CRA 6 CLLE 92  10.944446 -74.825528
# 9         CALLE 99 CR 56  11.016135 -74.826478
#
#    CANT_HERIDOS_EN _SITIO_ACCIDENTE  CANT_MUERTOS_EN _SITIO_ACCIDENTE  \
# 0                               1.0                               0.0
# 1                               1.0                               0.0
# 2                               0.0                               0.0
# 3                               0.0                               0.0
# 4                               2.0                               0.0
# 5                               0.0                               0.0
# 6                               2.0                               0.0
# 7                               1.0                               0.0
# 8                               0.0                               0.0
# 9                               0.0                               0.0
#
#    CANTIDAD_ACCIDENTES    ZONA
# 0                    1     SUR
# 1                    1   NORTE
# 2                    1  CENTRO
# 3                    1   NORTE
# 4                    1  CENTRO
# 5                    1  CENTRO
# 6                    1  CENTRO
# 7                    1     SUR
# 8                    1     SUR
# 9                    1   NORTE

# %% [markdown]
# ### Transformación de características
# Utilizando el método *apply* de Pandas, se crea la nueva columna pasando una función que recibirá por parametro el día de la semana en tipo cadena y retornará la cadena 'DIA DE SEMANA' o 'FIN DE SEMANA' según corresponda.

# %%
def transformation(day):
    weekend_days = ['Vie', 'Sab', 'Dom']
    if day in weekend_days:
        return 'FIN DE SEMANA'
    else:
        return 'DIA DE SEMANA'
    
day_of_week = pd.DataFrame()
day_of_week['DIA_SEMANA_ACCIDENTE'] = df['DIA_ACCIDENTE'].copy().apply(transformation)
day_of_week.head()
# Out:
#   DIA_SEMANA_ACCIDENTE
# 0        FIN DE SEMANA
# 1        DIA DE SEMANA
# 2        DIA DE SEMANA
# 3        DIA DE SEMANA
# 4        DIA DE SEMANA

# %% [markdown]
# ### Añadiendo la nueva columna
# Se añade la nueva columna al dataframe que contiene los datos.

# %%
df = pd.concat([df[:], day_of_week[:]], axis='columns')
df.head(10)
# Out:
#       FECHA_ACCIDENTE  AÑO_ACCIDENTE  MES_ACCIDENTE DIA_ACCIDENTE  \
# 0 2017-12-24 21:30:00           2017             12           Dom
# 1 2015-01-01 14:10:00           2015              1           Jue
# 2 2015-01-01 14:15:00           2015              1           Jue
# 3 2015-01-01 14:20:00           2015              1           Jue
# 4 2015-01-01 15:30:00           2015              1           Jue
# 5 2015-01-01 04:20:00           2015              1           Jue
# 6 2015-01-01 16:40:00           2015              1           Jue
# 7 2015-01-01 16:50:00           2015              1           Jue
# 8 2015-01-01 06:00:00           2015              1           Jue
# 9 2015-01-01 19:50:00           2015              1           Jue
#
#   HORA_ACCIDENTE MOMENTO_DIA GRAVEDAD_ACCIDENTE CLASE_ACCIDENTE  \
# 0    09:30:00:PM       Noche        Con heridos          Choque
# 1    02:10:00:PM       Tarde        Con heridos          Choque
# 2    02:15:00:PM       Tarde         Solo daños          Choque
# 3    02:20:00:PM       Tarde         Solo daños          Choque
# 4    03:30:00:PM       Tarde        Con heridos          Choque
# 5    04:20:00:AM   Madrugada         Solo daños          Choque
# 6    04:40:00:PM       Tarde        Con heridos          Choque
# 7    04:50:00:PM       Tarde        Con heridos       Atropello
# 8    06:00:00:AM      Mañana         Solo daños          Choque
# 9    07:50:00:PM       Noche         Solo daños          Choque
#
#   SITIO_EXACTO_ACCIDENTE    LATITUD   LONGITUD  \
# 0            CR 6  CL 94  10.946586 -74.826513
# 1          VIA 40 CON 77  11.016189 -74.795327
# 2         CALLE 14 CR 13  10.952965 -74.771882
# 3           CL 74 CR 38C  10.985707 -74.812420
# 4            CL 45 CR 19  10.958396 -74.794710
# 5         CRA 15 CLLE 21  10.953501 -74.776203
# 6         CRA 14 CLLE 35  10.951457 -74.788801
# 7          CRA 6 CLLE 90  10.944943 -74.823909
# 8          CRA 6 CLLE 92  10.944446 -74.825528
# 9         CALLE 99 CR 56  11.016135 -74.826478
#
#    CANT_HERIDOS_EN _SITIO_ACCIDENTE  CANT_MUERTOS_EN _SITIO_ACCIDENTE  \
# 0                               1.0                               0.0
# 1                               1.0                               0.0
# 2                               0.0                               0.0
# 3                               0.0                               0.0
# 4                               2.0                               0.0
# 5                               0.0                               0.0
# 6                               2.0                               0.0
# 7                               1.0                               0.0
# 8                               0.0                               0.0
# 9                               0.0                               0.0
#
#    CANTIDAD_ACCIDENTES    ZONA DIA_SEMANA_ACCIDENTE
# 0                    1     SUR        FIN DE SEMANA
# 1                    1   NORTE        DIA DE SEMANA
# 2                    1  CENTRO        DIA DE SEMANA
# 3                    1   NORTE        DIA DE SEMANA
# 4                    1  CENTRO        DIA DE SEMANA
# 5                    1  CENTRO        DIA DE SEMANA
# 6                    1  CENTRO        DIA DE SEMANA
# 7                    1     SUR        DIA DE SEMANA
# 8                    1     SUR        DIA DE SEMANA
# 9                    1   NORTE        DIA DE SEMANA

# %% [markdown]
# ### Versión final del dataset
# La version final del dataset se exporta en formato CSV para la fase de anàlisis.

# %%
df.to_csv('../../../data/processed/Accidentes_clean.csv', index=False)
